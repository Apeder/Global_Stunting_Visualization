# %%
#http://rmaps.github.io/blog/posts/animated-choropleths/
malnutrition_data_raw <- read.csv('./clean_analysis/UNICEF_child_malnutrition_Sept_2015.csv')

# %%
# Distributions would look good as violin plots using ggplot2
summary(malnutrition_data_raw)
# Out:
#        X          ISO_country                              country_name
#  Min.   :  0.0   BGD    : 23   BANGLADESH                        : 23
#  1st Qu.:194.2   VEN    : 21   VENEZUELA (BOLIVARIAN REPUBLIC OF): 21
#  Median :388.5   JAM    : 19   JAMAICA                           : 19
#  Mean   :388.5   VNM    : 16   VIET NAM                          : 16
#  3rd Qu.:582.8   CHL    : 15   CHILE                             : 15
#  Max.   :777.0   IDN    : 15   INDONESIA                         : 15
#                  (Other):669   (Other)                           :669
#       Year                  WB_income_region  sample_size      severe_wasting
#  Min.   :1983                       :  1     Min.   :    267   Min.   : 0.00
#  1st Qu.:1995   High income: nonOECD: 66     1st Qu.:   2600   1st Qu.: 0.80
#  Median :2002   High income: OECD   : 29     Median :   4638   Median : 1.80
#  Mean   :2002   Low income          :169     Mean   :  90294   Mean   : 2.41
#  3rd Qu.:2008   Lower middle income :306     3rd Qu.:  10225   3rd Qu.: 3.20
#  Max.   :2015   Upper middle income :207     Max.   :9999999   Max.   :15.90
#                                              NA's   :38        NA's   :231
#     wasting        overweight        stunting      underweight
#  Min.   : 0.00   Min.   : 0.000   Min.   : 0.00   Min.   : 0.00
#  1st Qu.: 3.00   1st Qu.: 3.200   1st Qu.:17.38   1st Qu.: 4.80
#  Median : 6.00   Median : 5.800   Median :29.90   Median :13.35
#  Mean   : 7.24   Mean   : 6.696   Mean   :29.91   Mean   :16.23
#  3rd Qu.:10.20   3rd Qu.: 9.000   3rd Qu.:41.50   3rd Qu.:23.82
#  Max.   :26.00   Max.   :30.000   Max.   :73.60   Max.   :66.80
#  NA's   :44      NA's   :151      NA's   :34      NA's   :14
#                                           notes
#                                              :446
#  Converted estimates                         :144
#  Age-adjusted;                               : 41
#  (pending reanalysis)                        : 35
#   Adjusted NR to NA; nutritional surveillance: 13
#  Age-adjusted; converted estimates           : 13
#  (Other)                                     : 86
#                                                        author
#                                                           : 95
#  Ministry of Health.                                      : 24
#  Ministerio de Salud.                                     : 15
#  Helen Keller International (HKI) Bangladesh.             : 12
#  Oficina SISVAN.                                          : 11
#  Administration of Food and Nutrition, Ministry of Health.:  9
#  (Other)                                                  :612
#                                                                                                                                                                                                                                                 source
#  Annual national nutrition monitoring. Nutrition Surveillance Department. Hanoi, Vietnam: National Institute of Nutrition, 2009 (and additional analysis).                                                                                         :  8
#  Ficha técnica: Evaluación antropométrica nutricional en menores de 5 años según criterios internacionales. Caracas, Venezuela: Gobierno Bolivariano de Venezuela, Ministerio del Poder Popular para la Salud, INN, 2012 (and additional analysis).:  8
#  Kuwait nutrition surveillance system, 2005 report: 2001-2005 trends. Kuwait, State of Kuwait: Administration of Food and Nutrition, Ministry of Health, 2006 (and additional analysis).                                                           :  5
#  Analisis del estado nutricional de la poblacion Costarricense 1992. Departamento de Nutricion y Atencion Integral, Seccion Vigilancia Nutricional. San Jose, Costa Rica, 1994 (and additional analysis).                                          :  4
#  Annual reports, 1990-1993. Family Health Information System. Information and Documentation Unit. Kuala Lumpur, Malaysia, 1994 (and additional analysis).                                                                                          :  4
#  Kuwait nutrition surveillance system: 2006-2009 trends. Kuwait, State of Kuwait: Administration of Food and Nutrition, Ministry of Health, 2010 (and additional analysis).                                                                        :  4
#  (Other)                                                                                                                                                                                                                                           :745
#   under_5_pop
#  Min.   :     1.0
#  1st Qu.:   450.4
#  Median :  1698.0
#  Mean   :  6106.9
#  3rd Qu.:  4159.5
#  Max.   :133332.7

# %%
long_dat <- malnutrition_data_raw[,c('Year', 'ISO_country', 'stunting')]

clean_dat <- na.omit(long_dat)

clean_dat$Year <- as.numeric(clean_dat$Year)

# clean_dat$Year <- strptime(clean_dat$Year, "%Y")
# clean_dat$Year <- as.POSIXct(clean_dat$Year)

clean_dat$ISO_country <- as.character(clean_dat$ISO_country)

head(clean_dat)
# Out:
#   Year ISO_country stunting
# 1 1997         AFG     53.2
# 2 2004         AFG     59.3
# 3 2013         AFG     40.9
# 4 1997         ALB     20.4
# 5 2000         ALB     39.2
# 6 2005         ALB     27.0

# %%
str(clean_dat)
# Out:
# 'data.frame':	744 obs. of  3 variables:
#  $ Year       : num  1997 2004 2013 1997 2000 ...
#  $ ISO_country: chr  "AFG" "AFG" "AFG" "ALB" ...
#  $ stunting   : num  53.2 59.3 40.9 20.4 39.2 27 23.1 16.9 22.9 22.5 ...
#  - attr(*, "na.action")=Class 'omit'  Named int [1:34] 58 69 71 72 73 87 116 164 165 166 ...
#   .. ..- attr(*, "names")= chr [1:34] "58" "69" "71" "72" ...

# %%
#Discretize the data by cutting into sextiles. 
clean_dat_disc <- transform(clean_dat, 
                            fillKey = cut(stunting, quantile(stunting, seq(0,1,1/5)), 
                                                     labels=LETTERS[1:5]))

# %%
head(clean_dat_disc)
# Out:
#   Year ISO_country stunting fillKey
# 1 1997         AFG     53.2       E
# 2 2004         AFG     59.3       E
# 3 2013         AFG     40.9       D
# 4 1997         ALB     20.4       B
# 5 2000         ALB     39.2       D
# 6 2005         ALB     27.0       C

# %%
fills = setNames(
    c(RColorBrewer::brewer.pal(5, 'YlOrRd'), 'white'), c(LETTERS[1:5], 'defaultFill')
)

# %%
library(plyr)
library(rMaps)

clean_dat_disp <- dlply(na.omit(clean_dat_disc), "Year", function(x){
    y=toJSONArray2(x, json=F)
    names(y)=lapply(y, '[[', 'ISO_country')
    return(y)
})

# %%
options(rcharts.cdn=TRUE)
map <- Datamaps$new()
map$set(
    dom = 'chart_1',
    scope='world',
    fills=fills,
    data=clean_dat_disp,
    legend=TRUE,
    labels=TRUE
)
    
map

# %%
head(clean_dat_disp)
# Out:
# $`1983`
# $`1983`$PNG
# $`1983`$PNG$Year
# [1] 1983
#
# $`1983`$PNG$ISO_country
# [1] "PNG"
#
# $`1983`$PNG$stunting
# [1] 46
#
# $`1983`$PNG$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
#
# $`1985`
# $`1985`$CPV
# $`1985`$CPV$Year
# [1] 1985
#
# $`1985`$CPV$ISO_country
# [1] "CPV"
#
# $`1985`$CPV$stunting
# [1] 26.8
#
# $`1985`$CPV$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1985`$KIR
# $`1985`$KIR$Year
# [1] 1985
#
# $`1985`$KIR$ISO_country
# [1] "KIR"
#
# $`1985`$KIR$stunting
# [1] 34.4
#
# $`1985`$KIR$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1985`$MUS
# $`1985`$MUS$Year
# [1] 1985
#
# $`1985`$MUS$ISO_country
# [1] "MUS"
#
# $`1985`$MUS$stunting
# [1] 27.3
#
# $`1985`$MUS$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1985`$NER
# $`1985`$NER$Year
# [1] 1985
#
# $`1985`$NER$ISO_country
# [1] "NER"
#
# $`1985`$NER$stunting
# [1] 43.8
#
# $`1985`$NER$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
#
# $`1986`
# $`1986`$BGD
# $`1986`$BGD$Year
# [1] 1986
#
# $`1986`$BGD$ISO_country
# [1] "BGD"
#
# $`1986`$BGD$stunting
# [1] 70.9
#
# $`1986`$BGD$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1986`$CHL
# $`1986`$CHL$Year
# [1] 1986
#
# $`1986`$CHL$ISO_country
# [1] "CHL"
#
# $`1986`$CHL$stunting
# [1] 13.5
#
# $`1986`$CHL$fillKey
# [1] A
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1986`$COL
# $`1986`$COL$Year
# [1] 1986
#
# $`1986`$COL$ISO_country
# [1] "COL"
#
# $`1986`$COL$stunting
# [1] 26.6
#
# $`1986`$COL$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1986`$CIV
# $`1986`$CIV$Year
# [1] 1986
#
# $`1986`$CIV$ISO_country
# [1] "CIV"
#
# $`1986`$CIV$stunting
# [1] 22.5
#
# $`1986`$CIV$fillKey
# [1] B
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1986`$DOM
# $`1986`$DOM$Year
# [1] 1986
#
# $`1986`$DOM$ISO_country
# [1] "DOM"
#
# $`1986`$DOM$stunting
# [1] 20.4
#
# $`1986`$DOM$fillKey
# [1] B
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1986`$ECU
# $`1986`$ECU$Year
# [1] 1986
#
# $`1986`$ECU$ISO_country
# [1] "ECU"
#
# $`1986`$ECU$stunting
# [1] 40.2
#
# $`1986`$ECU$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1986`$PAK
# $`1986`$PAK$Year
# [1] 1986
#
# $`1986`$PAK$ISO_country
# [1] "PAK"
#
# $`1986`$PAK$stunting
# [1] 62.5
#
# $`1986`$PAK$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1986`$STP
# $`1986`$STP$Year
# [1] 1986
#
# $`1986`$STP$ISO_country
# [1] "STP"
#
# $`1986`$STP$stunting
# [1] 32
#
# $`1986`$STP$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1986`$SEN
# $`1986`$SEN$Year
# [1] 1986
#
# $`1986`$SEN$ISO_country
# [1] "SEN"
#
# $`1986`$SEN$stunting
# [1] 26.5
#
# $`1986`$SEN$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1986`$TON
# $`1986`$TON$Year
# [1] 1986
#
# $`1986`$TON$ISO_country
# [1] "TON"
#
# $`1986`$TON$stunting
# [1] 2.2
#
# $`1986`$TON$fillKey
# [1] A
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
#
# $`1987`
# $`1987`$DZA
# $`1987`$DZA$Year
# [1] 1987
#
# $`1987`$DZA$ISO_country
# [1] "DZA"
#
# $`1987`$DZA$stunting
# [1] 16.9
#
# $`1987`$DZA$fillKey
# [1] B
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$BTN
# $`1987`$BTN$Year
# [1] 1987
#
# $`1987`$BTN$ISO_country
# [1] "BTN"
#
# $`1987`$BTN$stunting
# [1] 60.9
#
# $`1987`$BTN$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$BDI
# $`1987`$BDI$Year
# [1] 1987
#
# $`1987`$BDI$ISO_country
# [1] "BDI"
#
# $`1987`$BDI$stunting
# [1] 56.2
#
# $`1987`$BDI$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$CHN
# $`1987`$CHN$Year
# [1] 1987
#
# $`1987`$CHN$ISO_country
# [1] "CHN"
#
# $`1987`$CHN$stunting
# [1] 38.3
#
# $`1987`$CHN$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$COG
# $`1987`$COG$Year
# [1] 1987
#
# $`1987`$COG$ISO_country
# [1] "COG"
#
# $`1987`$COG$stunting
# [1] 30.1
#
# $`1987`$COG$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$GTM
# $`1987`$GTM$Year
# [1] 1987
#
# $`1987`$GTM$ISO_country
# [1] "GTM"
#
# $`1987`$GTM$stunting
# [1] 66.2
#
# $`1987`$GTM$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$HND
# $`1987`$HND$Year
# [1] 1987
#
# $`1987`$HND$ISO_country
# [1] "HND"
#
# $`1987`$HND$stunting
# [1] 43.3
#
# $`1987`$HND$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$KEN
# $`1987`$KEN$Year
# [1] 1987
#
# $`1987`$KEN$ISO_country
# [1] "KEN"
#
# $`1987`$KEN$stunting
# [1] 37
#
# $`1987`$KEN$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$MLI
# $`1987`$MLI$Year
# [1] 1987
#
# $`1987`$MLI$ISO_country
# [1] "MLI"
#
# $`1987`$MLI$stunting
# [1] 35.8
#
# $`1987`$MLI$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$MAR
# $`1987`$MAR$Year
# [1] 1987
#
# $`1987`$MAR$ISO_country
# [1] "MAR"
#
# $`1987`$MAR$stunting
# [1] 34.5
#
# $`1987`$MAR$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$PHL
# $`1987`$PHL$Year
# [1] 1987
#
# $`1987`$PHL$ISO_country
# [1] "PHL"
#
# $`1987`$PHL$stunting
# [1] 44.7
#
# $`1987`$PHL$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$LKA
# $`1987`$LKA$Year
# [1] 1987
#
# $`1987`$LKA$ISO_country
# [1] "LKA"
#
# $`1987`$LKA$stunting
# [1] 32.3
#
# $`1987`$LKA$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$THA
# $`1987`$THA$Year
# [1] 1987
#
# $`1987`$THA$ISO_country
# [1] "THA"
#
# $`1987`$THA$stunting
# [1] 24.6
#
# $`1987`$THA$fillKey
# [1] B
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$TTO
# $`1987`$TTO$Year
# [1] 1987
#
# $`1987`$TTO$ISO_country
# [1] "TTO"
#
# $`1987`$TTO$stunting
# [1] 6.3
#
# $`1987`$TTO$fillKey
# [1] A
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$URY
# $`1987`$URY$Year
# [1] 1987
#
# $`1987`$URY$ISO_country
# [1] "URY"
#
# $`1987`$URY$stunting
# [1] 21
#
# $`1987`$URY$fillKey
# [1] B
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1987`$VEN
# $`1987`$VEN$Year
# [1] 1987
#
# $`1987`$VEN$ISO_country
# [1] "VEN"
#
# $`1987`$VEN$stunting
# [1] 7
#
# $`1987`$VEN$fillKey
# [1] A
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
#
# $`1988`
# $`1988`$EGY
# $`1988`$EGY$Year
# [1] 1988
#
# $`1988`$EGY$ISO_country
# [1] "EGY"
#
# $`1988`$EGY$stunting
# [1] 34
#
# $`1988`$EGY$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1988`$SLV
# $`1988`$SLV$Year
# [1] 1988
#
# $`1988`$SLV$ISO_country
# [1] "SLV"
#
# $`1988`$SLV$stunting
# [1] 36.7
#
# $`1988`$SLV$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1988`$GHA
# $`1988`$GHA$Year
# [1] 1988
#
# $`1988`$GHA$ISO_country
# [1] "GHA"
#
# $`1988`$GHA$stunting
# [1] 42.6
#
# $`1988`$GHA$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1988`$MRT
# $`1988`$MRT$Year
# [1] 1988
#
# $`1988`$MRT$ISO_country
# [1] "MRT"
#
# $`1988`$MRT$stunting
# [1] 40.2
#
# $`1988`$MRT$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1988`$MEX
# $`1988`$MEX$Year
# [1] 1988
#
# $`1988`$MEX$ISO_country
# [1] "MEX"
#
# $`1988`$MEX$stunting
# [1] 28.7
#
# $`1988`$MEX$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1988`$SYC
# $`1988`$SYC$Year
# [1] 1988
#
# $`1988`$SYC$ISO_country
# [1] "SYC"
#
# $`1988`$SYC$stunting
# [1] 7.7
#
# $`1988`$SYC$fillKey
# [1] A
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1988`$TGO
# $`1988`$TGO$Year
# [1] 1988
#
# $`1988`$TGO$ISO_country
# [1] "TGO"
#
# $`1988`$TGO$stunting
# [1] 40.7
#
# $`1988`$TGO$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1988`$TUN
# $`1988`$TUN$Year
# [1] 1988
#
# $`1988`$TUN$ISO_country
# [1] "TUN"
#
# $`1988`$TUN$stunting
# [1] 18.5
#
# $`1988`$TUN$fillKey
# [1] B
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1988`$UGA
# $`1988`$UGA$Year
# [1] 1988
#
# $`1988`$UGA$ISO_country
# [1] "UGA"
#
# $`1988`$UGA$stunting
# [1] 47.6
#
# $`1988`$UGA$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1988`$VNM
# $`1988`$VNM$Year
# [1] 1988
#
# $`1988`$VNM$ISO_country
# [1] "VNM"
#
# $`1988`$VNM$stunting
# [1] 61.3
#
# $`1988`$VNM$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1988`$ZWE
# $`1988`$ZWE$Year
# [1] 1988
#
# $`1988`$ZWE$ISO_country
# [1] "ZWE"
#
# $`1988`$ZWE$stunting
# [1] 31
#
# $`1988`$ZWE$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
#
# $`1989`
# $`1989`$BHR
# $`1989`$BHR$Year
# [1] 1989
#
# $`1989`$BHR$ISO_country
# [1] "BHR"
#
# $`1989`$BHR$stunting
# [1] 13.9
#
# $`1989`$BHR$fillKey
# [1] A
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1989`$BOL
# $`1989`$BOL$Year
# [1] 1989
#
# $`1989`$BOL$ISO_country
# [1] "BOL"
#
# $`1989`$BOL$stunting
# [1] 44
#
# $`1989`$BOL$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1989`$BRA
# $`1989`$BRA$Year
# [1] 1989
#
# $`1989`$BRA$ISO_country
# [1] "BRA"
#
# $`1989`$BRA$stunting
# [1] 19.4
#
# $`1989`$BRA$fillKey
# [1] B
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1989`$COL
# $`1989`$COL$Year
# [1] 1989
#
# $`1989`$COL$ISO_country
# [1] "COL"
#
# $`1989`$COL$stunting
# [1] 21.8
#
# $`1989`$COL$fillKey
# [1] B
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1989`$DJI
# $`1989`$DJI$Year
# [1] 1989
#
# $`1989`$DJI$ISO_country
# [1] "DJI"
#
# $`1989`$DJI$stunting
# [1] 28
#
# $`1989`$DJI$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1989`$IND
# $`1989`$IND$Year
# [1] 1989
#
# $`1989`$IND$ISO_country
# [1] "IND"
#
# $`1989`$IND$stunting
# [1] 62.7
#
# $`1989`$IND$fillKey
# [1] E
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1989`$JAM
# $`1989`$JAM$Year
# [1] 1989
#
# $`1989`$JAM$ISO_country
# [1] "JAM"
#
# $`1989`$JAM$stunting
# [1] 12.4
#
# $`1989`$JAM$fillKey
# [1] A
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1989`$MEX
# $`1989`$MEX$Year
# [1] 1989
#
# $`1989`$MEX$ISO_country
# [1] "MEX"
#
# $`1989`$MEX$stunting
# [1] 26
#
# $`1989`$MEX$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1989`$SLE
# $`1989`$SLE$Year
# [1] 1989
#
# $`1989`$SLE$ISO_country
# [1] "SLE"
#
# $`1989`$SLE$stunting
# [1] 41.4
#
# $`1989`$SLE$fillKey
# [1] D
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"
#
# $`1989`$SLB
# $`1989`$SLB$Year
# [1] 1989
#
# $`1989`$SLB$ISO_country
# [1] "SLB"
#
# $`1989`$SLB$stunting
# [1] 33.7
#
# $`1989`$SLB$fillKey
# [1] C
# Levels: A B C D E
#
# attr(,"vars")
# [1] "Year"

# %%
str(clean_dat_disp)
# Out:
# List of 32
#  $ 1983:List of 1
#   ..$ PNG:List of 4
#   .. ..$ Year       : num 1983
#   .. ..$ ISO_country: chr "PNG"
#   .. ..$ stunting   : num 46
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1985:List of 4
#   ..$ CPV:List of 4
#   .. ..$ Year       : num 1985
#   .. ..$ ISO_country: chr "CPV"
#   .. ..$ stunting   : num 26.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KIR:List of 4
#   .. ..$ Year       : num 1985
#   .. ..$ ISO_country: chr "KIR"
#   .. ..$ stunting   : num 34.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MUS:List of 4
#   .. ..$ Year       : num 1985
#   .. ..$ ISO_country: chr "MUS"
#   .. ..$ stunting   : num 27.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NER:List of 4
#   .. ..$ Year       : num 1985
#   .. ..$ ISO_country: chr "NER"
#   .. ..$ stunting   : num 43.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1986:List of 10
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 1986
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 70.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CHL:List of 4
#   .. ..$ Year       : num 1986
#   .. ..$ ISO_country: chr "CHL"
#   .. ..$ stunting   : num 13.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ COL:List of 4
#   .. ..$ Year       : num 1986
#   .. ..$ ISO_country: chr "COL"
#   .. ..$ stunting   : num 26.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CIV:List of 4
#   .. ..$ Year       : num 1986
#   .. ..$ ISO_country: chr "CIV"
#   .. ..$ stunting   : num 22.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ DOM:List of 4
#   .. ..$ Year       : num 1986
#   .. ..$ ISO_country: chr "DOM"
#   .. ..$ stunting   : num 20.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ECU:List of 4
#   .. ..$ Year       : num 1986
#   .. ..$ ISO_country: chr "ECU"
#   .. ..$ stunting   : num 40.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PAK:List of 4
#   .. ..$ Year       : num 1986
#   .. ..$ ISO_country: chr "PAK"
#   .. ..$ stunting   : num 62.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ STP:List of 4
#   .. ..$ Year       : num 1986
#   .. ..$ ISO_country: chr "STP"
#   .. ..$ stunting   : num 32
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SEN:List of 4
#   .. ..$ Year       : num 1986
#   .. ..$ ISO_country: chr "SEN"
#   .. ..$ stunting   : num 26.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TON:List of 4
#   .. ..$ Year       : num 1986
#   .. ..$ ISO_country: chr "TON"
#   .. ..$ stunting   : num 2.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1987:List of 16
#   ..$ DZA:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "DZA"
#   .. ..$ stunting   : num 16.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BTN:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "BTN"
#   .. ..$ stunting   : num 60.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BDI:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "BDI"
#   .. ..$ stunting   : num 56.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CHN:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "CHN"
#   .. ..$ stunting   : num 38.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ COG:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "COG"
#   .. ..$ stunting   : num 30.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GTM:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "GTM"
#   .. ..$ stunting   : num 66.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ HND:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "HND"
#   .. ..$ stunting   : num 43.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KEN:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "KEN"
#   .. ..$ stunting   : num 37
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MLI:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "MLI"
#   .. ..$ stunting   : num 35.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MAR:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "MAR"
#   .. ..$ stunting   : num 34.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PHL:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "PHL"
#   .. ..$ stunting   : num 44.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LKA:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "LKA"
#   .. ..$ stunting   : num 32.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ THA:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "THA"
#   .. ..$ stunting   : num 24.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TTO:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "TTO"
#   .. ..$ stunting   : num 6.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ URY:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "URY"
#   .. ..$ stunting   : num 21
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VEN:List of 4
#   .. ..$ Year       : num 1987
#   .. ..$ ISO_country: chr "VEN"
#   .. ..$ stunting   : num 7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1988:List of 11
#   ..$ EGY:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "EGY"
#   .. ..$ stunting   : num 34
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SLV:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "SLV"
#   .. ..$ stunting   : num 36.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GHA:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "GHA"
#   .. ..$ stunting   : num 42.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MRT:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "MRT"
#   .. ..$ stunting   : num 40.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MEX:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "MEX"
#   .. ..$ stunting   : num 28.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SYC:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "SYC"
#   .. ..$ stunting   : num 7.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TGO:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "TGO"
#   .. ..$ stunting   : num 40.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TUN:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "TUN"
#   .. ..$ stunting   : num 18.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ UGA:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "UGA"
#   .. ..$ stunting   : num 47.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VNM:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "VNM"
#   .. ..$ stunting   : num 61.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ZWE:List of 4
#   .. ..$ Year       : num 1988
#   .. ..$ ISO_country: chr "ZWE"
#   .. ..$ stunting   : num 31
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1989:List of 10
#   ..$ BHR:List of 4
#   .. ..$ Year       : num 1989
#   .. ..$ ISO_country: chr "BHR"
#   .. ..$ stunting   : num 13.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BOL:List of 4
#   .. ..$ Year       : num 1989
#   .. ..$ ISO_country: chr "BOL"
#   .. ..$ stunting   : num 44
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BRA:List of 4
#   .. ..$ Year       : num 1989
#   .. ..$ ISO_country: chr "BRA"
#   .. ..$ stunting   : num 19.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ COL:List of 4
#   .. ..$ Year       : num 1989
#   .. ..$ ISO_country: chr "COL"
#   .. ..$ stunting   : num 21.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ DJI:List of 4
#   .. ..$ Year       : num 1989
#   .. ..$ ISO_country: chr "DJI"
#   .. ..$ stunting   : num 28
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ IND:List of 4
#   .. ..$ Year       : num 1989
#   .. ..$ ISO_country: chr "IND"
#   .. ..$ stunting   : num 62.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JAM:List of 4
#   .. ..$ Year       : num 1989
#   .. ..$ ISO_country: chr "JAM"
#   .. ..$ stunting   : num 12.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MEX:List of 4
#   .. ..$ Year       : num 1989
#   .. ..$ ISO_country: chr "MEX"
#   .. ..$ stunting   : num 26
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SLE:List of 4
#   .. ..$ Year       : num 1989
#   .. ..$ ISO_country: chr "SLE"
#   .. ..$ stunting   : num 41.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SLB:List of 4
#   .. ..$ Year       : num 1989
#   .. ..$ ISO_country: chr "SLB"
#   .. ..$ stunting   : num 33.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1990:List of 10
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 1990
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 63.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CHN:List of 4
#   .. ..$ Year       : num 1990
#   .. ..$ ISO_country: chr "CHN"
#   .. ..$ stunting   : num 32.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ HTI:List of 4
#   .. ..$ Year       : num 1990
#   .. ..$ ISO_country: chr "HTI"
#   .. ..$ stunting   : num 40.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JOR:List of 4
#   .. ..$ Year       : num 1990
#   .. ..$ ISO_country: chr "JOR"
#   .. ..$ stunting   : num 20.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MRT:List of 4
#   .. ..$ Year       : num 1990
#   .. ..$ ISO_country: chr "MRT"
#   .. ..$ stunting   : num 54.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NGA:List of 4
#   .. ..$ Year       : num 1990
#   .. ..$ ISO_country: chr "NGA"
#   .. ..$ stunting   : num 50.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PRY:List of 4
#   .. ..$ Year       : num 1990
#   .. ..$ ISO_country: chr "PRY"
#   .. ..$ stunting   : num 18.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PHL:List of 4
#   .. ..$ Year       : num 1990
#   .. ..$ ISO_country: chr "PHL"
#   .. ..$ stunting   : num 43.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SLE:List of 4
#   .. ..$ Year       : num 1990
#   .. ..$ ISO_country: chr "SLE"
#   .. ..$ stunting   : num 40.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VEN:List of 4
#   .. ..$ Year       : num 1990
#   .. ..$ ISO_country: chr "VEN"
#   .. ..$ stunting   : num 18.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1991:List of 16
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 73.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CMR:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "CMR"
#   .. ..$ stunting   : num 36.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CZE:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "CZE"
#   .. ..$ stunting   : num 3.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ DOM:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "DOM"
#   .. ..$ stunting   : num 21.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ EGY:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "EGY"
#   .. ..$ stunting   : num 34.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ IRQ:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "IRQ"
#   .. ..$ stunting   : num 27.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JAM:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "JAM"
#   .. ..$ stunting   : num 9.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MMR:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "MMR"
#   .. ..$ stunting   : num 53.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ OMN:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "OMN"
#   .. ..$ stunting   : num 24.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PAK:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "PAK"
#   .. ..$ stunting   : num 54.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PER:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "PER"
#   .. ..$ stunting   : num 37.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ROU:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "ROU"
#   .. ..$ stunting   : num 11.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TZA:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "TZA"
#   .. ..$ stunting   : num 49.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ USA:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "USA"
#   .. ..$ stunting   : num 3.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VEN:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "VEN"
#   .. ..$ stunting   : num 18.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ YEM:List of 4
#   .. ..$ Year       : num 1991
#   .. ..$ ISO_country: chr "YEM"
#   .. ..$ stunting   : num 52.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1992:List of 21
#   ..$ DZA:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "DZA"
#   .. ..$ stunting   : num 22.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 71.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CHN:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "CHN"
#   .. ..$ stunting   : num 38
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ COM:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "COM"
#   .. ..$ stunting   : num 38.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ETH:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "ETH"
#   .. ..$ stunting   : num 66.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ HND:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "HND"
#   .. ..$ stunting   : num 42.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ IND:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "IND"
#   .. ..$ stunting   : num 61.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JAM:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "JAM"
#   .. ..$ stunting   : num 14.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LSO:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "LSO"
#   .. ..$ stunting   : num 39.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MDG:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "MDG"
#   .. ..$ stunting   : num 60.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MWI:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "MWI"
#   .. ..$ stunting   : num 55.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MNG:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "MNG"
#   .. ..$ stunting   : num 33.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MAR:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "MAR"
#   .. ..$ stunting   : num 29.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NAM:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "NAM"
#   .. ..$ stunting   : num 35.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NER:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "NER"
#   .. ..$ stunting   : num 48.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PAK:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "PAK"
#   .. ..$ stunting   : num 42.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PHL:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "PHL"
#   .. ..$ stunting   : num 40.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ RWA:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "RWA"
#   .. ..$ stunting   : num 56.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SEN:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "SEN"
#   .. ..$ stunting   : num 34.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VEN:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "VEN"
#   .. ..$ stunting   : num 18.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ZMB:List of 4
#   .. ..$ Year       : num 1992
#   .. ..$ ISO_country: chr "ZMB"
#   .. ..$ stunting   : num 46.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1993:List of 23
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 69.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BFA:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "BFA"
#   .. ..$ stunting   : num 40.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ EGY:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "EGY"
#   .. ..$ stunting   : num 31.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SLV:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "SLV"
#   .. ..$ stunting   : num 29.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ERI:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "ERI"
#   .. ..$ stunting   : num 69.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ FJI:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "FJI"
#   .. ..$ stunting   : num 4.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GHA:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "GHA"
#   .. ..$ stunting   : num 41.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ IND:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "IND"
#   .. ..$ stunting   : num 57.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JAM:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "JAM"
#   .. ..$ stunting   : num 13.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KEN:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "KEN"
#   .. ..$ stunting   : num 40.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LAO:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "LAO"
#   .. ..$ stunting   : num 53.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LSO:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "LSO"
#   .. ..$ stunting   : num 37.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MDG:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "MDG"
#   .. ..$ stunting   : num 54.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NIC:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "NIC"
#   .. ..$ stunting   : num 29.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NGA:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "NGA"
#   .. ..$ stunting   : num 43.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PHL:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "PHL"
#   .. ..$ stunting   : num 38.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SEN:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "SEN"
#   .. ..$ stunting   : num 33.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LKA:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "LKA"
#   .. ..$ stunting   : num 29.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SYR:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "SYR"
#   .. ..$ stunting   : num 32.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ THA:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "THA"
#   .. ..$ stunting   : num 21.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TUR:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "TUR"
#   .. ..$ stunting   : num 24.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VEN:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "VEN"
#   .. ..$ stunting   : num 17.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VNM:List of 4
#   .. ..$ Year       : num 1993
#   .. ..$ ISO_country: chr "VNM"
#   .. ..$ stunting   : num 61.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1994:List of 21
#   ..$ ARG:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "ARG"
#   .. ..$ stunting   : num 7.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 67.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BOL:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "BOL"
#   .. ..$ stunting   : num 37.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CPV:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "CPV"
#   .. ..$ stunting   : num 21.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CAF:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "CAF"
#   .. ..$ stunting   : num 41.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CHL:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "CHL"
#   .. ..$ stunting   : num 4.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CIV:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "CIV"
#   .. ..$ stunting   : num 34.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GIN:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "GIN"
#   .. ..$ stunting   : num 35.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ HTI:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "HTI"
#   .. ..$ stunting   : num 37.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ HND:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "HND"
#   .. ..$ stunting   : num 45.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JAM:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "JAM"
#   .. ..$ stunting   : num 11.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KEN:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "KEN"
#   .. ..$ stunting   : num 39.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LAO:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "LAO"
#   .. ..$ stunting   : num 52.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MDV:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "MDV"
#   .. ..$ stunting   : num 36.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MMR:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "MMR"
#   .. ..$ stunting   : num 58.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ OMN:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "OMN"
#   .. ..$ stunting   : num 21.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SAU:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "SAU"
#   .. ..$ stunting   : num 21.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ZAF:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "ZAF"
#   .. ..$ stunting   : num 31.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VEN:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "VEN"
#   .. ..$ stunting   : num 17.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VNM:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "VNM"
#   .. ..$ stunting   : num 52.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ZWE:List of 4
#   .. ..$ Year       : num 1994
#   .. ..$ ISO_country: chr "ZWE"
#   .. ..$ stunting   : num 28.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1995:List of 29
#   ..$ DZA:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "DZA"
#   .. ..$ stunting   : num 22.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BHR:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "BHR"
#   .. ..$ stunting   : num 13.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 65.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CHL:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "CHL"
#   .. ..$ stunting   : num 3.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CHN:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "CHN"
#   .. ..$ stunting   : num 31.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ COL:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "COL"
#   .. ..$ stunting   : num 19.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ COD:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "COD"
#   .. ..$ stunting   : num 51
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ EGY:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "EGY"
#   .. ..$ stunting   : num 34.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ERI:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "ERI"
#   .. ..$ stunting   : num 47.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GTM:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "GTM"
#   .. ..$ stunting   : num 55.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ IDN:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "IDN"
#   .. ..$ stunting   : num 48.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ IRN:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "IRN"
#   .. ..$ stunting   : num 24.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JAM:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "JAM"
#   .. ..$ stunting   : num 9.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KAZ:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "KAZ"
#   .. ..$ stunting   : num 23.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LBY:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "LBY"
#   .. ..$ stunting   : num 21.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MDG:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "MDG"
#   .. ..$ stunting   : num 55.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MWI:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "MWI"
#   .. ..$ stunting   : num 53.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MDV:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "MDV"
#   .. ..$ stunting   : num 33
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MUS:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "MUS"
#   .. ..$ stunting   : num 13.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MOZ:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "MOZ"
#   .. ..$ stunting   : num 59.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NPL:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "NPL"
#   .. ..$ stunting   : num 68.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ QAT:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "QAT"
#   .. ..$ stunting   : num 11.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ZAF:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "ZAF"
#   .. ..$ stunting   : num 28.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LKA:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "LKA"
#   .. ..$ stunting   : num 26.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SYR:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "SYR"
#   .. ..$ stunting   : num 26.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ THA:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "THA"
#   .. ..$ stunting   : num 18.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ UGA:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "UGA"
#   .. ..$ stunting   : num 45.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VEN:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "VEN"
#   .. ..$ stunting   : num 18.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ZMB:List of 4
#   .. ..$ Year       : num 1995
#   .. ..$ ISO_country: chr "ZMB"
#   .. ..$ stunting   : num 58.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1996:List of 33
#   ..$ AGO:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "AGO"
#   .. ..$ stunting   : num 61.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ARG:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "ARG"
#   .. ..$ stunting   : num 16.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ AZE:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "AZE"
#   .. ..$ stunting   : num 28
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 63.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BEN:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "BEN"
#   .. ..$ stunting   : num 39.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BWA:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "BWA"
#   .. ..$ stunting   : num 35.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BRA:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "BRA"
#   .. ..$ stunting   : num 13.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KHM:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "KHM"
#   .. ..$ stunting   : num 58.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CHL:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "CHL"
#   .. ..$ stunting   : num 3.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ COM:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "COM"
#   .. ..$ stunting   : num 40
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CRI:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "CRI"
#   .. ..$ stunting   : num 8.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ DJI:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "DJI"
#   .. ..$ stunting   : num 31.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ DOM:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "DOM"
#   .. ..$ stunting   : num 13.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GMB:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "GMB"
#   .. ..$ stunting   : num 36.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ HND:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "HND"
#   .. ..$ stunting   : num 38.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JAM:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "JAM"
#   .. ..$ stunting   : num 11.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KWT:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "KWT"
#   .. ..$ stunting   : num 5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LBN:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "LBN"
#   .. ..$ stunting   : num 17.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MLI:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "MLI"
#   .. ..$ stunting   : num 39.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MRT:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "MRT"
#   .. ..$ stunting   : num 49.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MEX:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "MEX"
#   .. ..$ stunting   : num 25.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NPL:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "NPL"
#   .. ..$ stunting   : num 65.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PER:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "PER"
#   .. ..$ stunting   : num 31.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ RWA:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "RWA"
#   .. ..$ stunting   : num 45.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SEN:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "SEN"
#   .. ..$ stunting   : num 28.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TGO:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "TGO"
#   .. ..$ stunting   : num 40.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TZA:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "TZA"
#   .. ..$ stunting   : num 49.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ UZB:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "UZB"
#   .. ..$ stunting   : num 39.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VUT:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "VUT"
#   .. ..$ stunting   : num 25.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VEN:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "VEN"
#   .. ..$ stunting   : num 19.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PSE:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "PSE"
#   .. ..$ stunting   : num 10.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ YEM:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "YEM"
#   .. ..$ stunting   : num 50.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ZMB:List of 4
#   .. ..$ Year       : num 1996
#   .. ..$ ISO_country: chr "ZMB"
#   .. ..$ stunting   : num 48.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 1997:List of 20
#   ..$ AFG:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "AFG"
#   .. ..$ stunting   : num 53.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ALB:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "ALB"
#   .. ..$ stunting   : num 20.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 59.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TCD:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "TCD"
#   .. ..$ stunting   : num 45
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ EGY:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "EGY"
#   .. ..$ stunting   : num 30.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GNQ:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "GNQ"
#   .. ..$ stunting   : num 38.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GUY:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "GUY"
#   .. ..$ stunting   : num 14
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ IND:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "IND"
#   .. ..$ stunting   : num 45.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JAM:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "JAM"
#   .. ..$ stunting   : num 8.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JOR:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "JOR"
#   .. ..$ stunting   : num 11.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KGZ:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "KGZ"
#   .. ..$ stunting   : num 36.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MDG:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "MDG"
#   .. ..$ stunting   : num 58.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MDV:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "MDV"
#   .. ..$ stunting   : num 46.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MAR:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "MAR"
#   .. ..$ stunting   : num 29
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MOZ:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "MOZ"
#   .. ..$ stunting   : num 48.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MMR:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "MMR"
#   .. ..$ stunting   : num 55.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PAN:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "PAN"
#   .. ..$ stunting   : num 21.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TUN:List of 4
#   .. ..$ Year       : num 1997
#   .. ..$ ISO_country: chr "TUN"
#   .. ..$ stunting   : num 11.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VEN:List of 4
#   .. ..$ Year       : num 1997
# ...
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "HTI"
#   .. ..$ stunting   : num 21.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ HND:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "HND"
#   .. ..$ stunting   : num 22.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JAM:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "JAM"
#   .. ..$ stunting   : num 5.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ JOR:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "JOR"
#   .. ..$ stunting   : num 7.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KWT:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "KWT"
#   .. ..$ stunting   : num 4.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KGZ:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "KGZ"
#   .. ..$ stunting   : num 17.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MRT:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "MRT"
#   .. ..$ stunting   : num 22
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MEX:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "MEX"
#   .. ..$ stunting   : num 13.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NER:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "NER"
#   .. ..$ stunting   : num 43
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PAK:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "PAK"
#   .. ..$ stunting   : num 45
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PRY:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "PRY"
#   .. ..$ stunting   : num 10.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PER:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "PER"
#   .. ..$ stunting   : num 18.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MDA:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "MDA"
#   .. ..$ stunting   : num 6.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LCA:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "LCA"
#   .. ..$ stunting   : num 2.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SEN:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "SEN"
#   .. ..$ stunting   : num 15.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SYC:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "SYC"
#   .. ..$ stunting   : num 7.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LKA:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "LKA"
#   .. ..$ stunting   : num 14.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TJK:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "TJK"
#   .. ..$ stunting   : num 26.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ THA:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "THA"
#   .. ..$ stunting   : num 16.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TON:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "TON"
#   .. ..$ stunting   : num 8.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TUN:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "TUN"
#   .. ..$ stunting   : num 10.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ UGA:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "UGA"
#   .. ..$ stunting   : num 34.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ USA:List of 4
#   .. ..$ Year       : num 2012
#   .. ..$ ISO_country: chr "USA"
#   .. ..$ stunting   : num 2.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 2013:List of 23
#   ..$ AFG:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "AFG"
#   .. ..$ stunting   : num 40.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ AZE:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "AZE"
#   .. ..$ stunting   : num 18
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 38.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CHL:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "CHL"
#   .. ..$ stunting   : num 1.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ COD:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "COD"
#   .. ..$ stunting   : num 42.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ DOM:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "DOM"
#   .. ..$ stunting   : num 7.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GMB:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "GMB"
#   .. ..$ stunting   : num 24.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ IDN:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "IDN"
#   .. ..$ stunting   : num 36.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KWT:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "KWT"
#   .. ..$ stunting   : num 4.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LBR:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "LBR"
#   .. ..$ stunting   : num 32.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MNG:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "MNG"
#   .. ..$ stunting   : num 10.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MNE:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "MNE"
#   .. ..$ stunting   : num 9.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NAM:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "NAM"
#   .. ..$ stunting   : num 23.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NGA:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "NGA"
#   .. ..$ stunting   : num 36.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PER:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "PER"
#   .. ..$ stunting   : num 17.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PHL:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "PHL"
#   .. ..$ stunting   : num 30.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SEN:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "SEN"
#   .. ..$ stunting   : num 19.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SLE:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "SLE"
#   .. ..$ stunting   : num 37.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TUR:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "TUR"
#   .. ..$ stunting   : num 9.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TZA:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "TZA"
#   .. ..$ stunting   : num 37.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VUT:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "VUT"
#   .. ..$ stunting   : num 28.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ VNM:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "VNM"
#   .. ..$ stunting   : num 19.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ZMB:List of 4
#   .. ..$ Year       : num 2013
#   .. ..$ ISO_country: chr "ZMB"
#   .. ..$ stunting   : num 40
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 2014:List of 27
#   ..$ BGD:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "BGD"
#   .. ..$ stunting   : num 36.1
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ BEN:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "BEN"
#   .. ..$ stunting   : num 34
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KHM:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "KHM"
#   .. ..$ stunting   : num 32.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ CHL:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "CHL"
#   .. ..$ stunting   : num 1.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ EGY:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "EGY"
#   .. ..$ stunting   : num 22.3
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SLV:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "SLV"
#   .. ..$ stunting   : num 14
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ETH:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "ETH"
#   .. ..$ stunting   : num 40.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GHA:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "GHA"
#   .. ..$ stunting   : num 18.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GNB:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "GNB"
#   .. ..$ stunting   : num 27.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ GUY:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "GUY"
#   .. ..$ stunting   : num 12
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ IND:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "IND"
#   .. ..$ stunting   : num 38.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KEN:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "KEN"
#   .. ..$ stunting   : num 26
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KWT:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "KWT"
#   .. ..$ stunting   : num 5.8
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ KGZ:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "KGZ"
#   .. ..$ stunting   : num 12.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ LSO:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "LSO"
#   .. ..$ stunting   : num 33.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ MWI:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "MWI"
#   .. ..$ stunting   : num 42.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NPL:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "NPL"
#   .. ..$ stunting   : num 37.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ NGA:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "NGA"
#   .. ..$ stunting   : num 32.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SEN:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "SEN"
#   .. ..$ stunting   : num 19.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 2
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SRB:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "SRB"
#   .. ..$ stunting   : num 6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SDN:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "SDN"
#   .. ..$ stunting   : num 38.2
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ SWZ:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "SWZ"
#   .. ..$ stunting   : num 25.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TGO:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "TGO"
#   .. ..$ stunting   : num 27.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ TZA:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "TZA"
#   .. ..$ stunting   : num 34.7
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ PSE:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "PSE"
#   .. ..$ stunting   : num 7.4
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 1
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ YEM:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "YEM"
#   .. ..$ stunting   : num 46.5
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 5
#   .. ..- attr(*, "vars")= chr "Year"
#   ..$ ZWE:List of 4
#   .. ..$ Year       : num 2014
#   .. ..$ ISO_country: chr "ZWE"
#   .. ..$ stunting   : num 27.6
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 3
#   .. ..- attr(*, "vars")= chr "Year"
#  $ 2015:List of 1
#   ..$ RWA:List of 4
#   .. ..$ Year       : num 2015
#   .. ..$ ISO_country: chr "RWA"
#   .. ..$ stunting   : num 37.9
#   .. ..$ fillKey    : Factor w/ 5 levels "A","B","C","D",..: 4
#   .. ..- attr(*, "vars")= chr "Year"
#  - attr(*, "split_type")= chr "data.frame"
#  - attr(*, "split_labels")='data.frame':	32 obs. of  1 variable:
#   ..$ Year: num [1:32] 1983 1985 1986 1987 1988 ...

# %%
map2=map$copy()
map2$set(
    bodyattr="ng-app ng-controller='rChartsCtrl'"
)
map2$addAssets(
    jshead="http://cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.1/angular.min.js"
)

# %%
map2$setTemplate(chartDiv="
    <div class='container'>
        <input id='slider' type='range' min=1983 max=2015 ng-model='year' width=200>
        <span ng-bind='year'</span>
        <div id='' class='rChart datamaps'></div>
        <script>
            function rChartsCtrl($scope){
                $scope.year=1083;
                $scope.$watch('year', function(newYear)){
                    map.updateChoropleth(chartParams.newData[newYear]);
        })
    }
    </script>"                
)

# %%
map2$set(newData=clean_dat_disp)
map2

# %%
library(rMaps)
library(rCharts)

ichoropleth <- function(x, data, pal, ncuts, animate, play, map, legend = TRUE, 
                        labels = TRUE, ...){
  d <- Datamaps$new()
  fml = lattice::latticeParseFormula(x, data = data)
  data = transform(data, 
    fillKey = cut(
      fml$left, 
      quantile(fml$left, seq(0, 1, 1/ncuts)),
      ordered_result = TRUE
    )
  )
  fillColors = RColorBrewer::brewer.pal(ncuts, pal)
  d$set(
    scope = map, 
    fills = as.list(setNames(fillColors, levels(data$fillKey))), 
    legend = legend,
    labels = labels,
    ...  
  ) 
if (!is.null(animate)){
    range_ = summary(data[[animate]])
    data = dlply(data, animate, function(x){
      y = toJSONArray2(x, json = F)
      names(y) = lapply(y, '[[', fml$right.name)
      return(y)
    })
    d$set(
      bodyattrs = "ng-app ng-controller='rChartsCtrl'"  
    )
    d$addAssets(
      jshead = "http://cdnjs.cloudflare.com/ajax/libs/angular.js/1.2.1/angular.min.js"
    )
    if (play == T){
      d$setTemplate(chartDiv = sprintf("
        <div class='container'>
         <button ng-click='animateMap()'>Play</button>
         <div id='{{chartId}}' class='rChart datamaps'></div>  
        </div>
        <script>
          function rChartsCtrl($scope, $timeout){
            $scope.year = %s;
              $scope.animateMap = function(){
              if ($scope.year > %s){
                return;
              }
              map{{chartId}}.updateChoropleth(chartParams.newData[$scope.year]);
              $scope.year += 1
              $timeout($scope.animateMap, 1000)
            }
          }
       </script>", range_[1], range_[6])
      )
      
    } else {
      d$setTemplate(chartDiv = sprintf("
        <div class='container'>
          <input id='slider' type='range' min=%s max=%s ng-model='year' width=200>
          <div id='{{chartId}}' class='rChart datamaps'></div>  
        </div>
        <script>
          function rChartsCtrl($scope){
            $scope.year = %s;
            $scope.$watch('year', function(newYear){
              map{{chartId}}.updateChoropleth(chartParams.newData[newYear]);
            })
          }
       </script>", range_[1], range_[6], range_[1])
      )
    }
    d$set(newData = data, data = data[[1]])
    
  } else {
    d$set(data = dlply(data, fml$right.name))
  }
  return(d)
}

# %%
ichoropleth(stunting ~ ISO_country, data=clean_dat, pal="Blues", animate="Year", ncuts=5,
            play=T, map='world')
